# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
from thesis.tracking.features import pupil_detector

# %%
image = cv.imread('/home/anton/data/eyedata/iris/images/casia4i/002/L/S1002L07.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(image)

# %%
pupil_detector(image)
# Out:
# [168.14683532714844,
#  143.51438903808594,
#  75.1337661743164,
#  72.34294128417969,
#  5.734516143798828]
